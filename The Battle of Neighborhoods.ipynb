# %% [markdown]
# # The Battle of Neighborhoods (Abu Dhabi & Dubai)

# %% [markdown]
# ### 1. Introduction: COFFEE SHOP IN UAE

# %% [markdown]
# In such a large and rich  culture city like Dubai, AbuDhabi,it will be competitive to start up coffee business. In this case my contractor is a humble Arab man who has contacted me to give advises and draw up essential lines of business prediction and back-up plans (but this part we will just discuss about predicting hot spot).

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np
# !pip install folium
import folium
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 7.8 MB/s  eta 0:00:01
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1

# %%
CLIENT_ID = 'QZNC24IIFPKZRH5NSHQJN3WDFBGPHHO1PP1F5MSQI0DA01KO' # your Foursquare ID
CLIENT_SECRET = 'PY4UPNJDJRDBRENFIDHVLIJ35QW14QEQBKKFXFE3ZVE1YZYY' # your Foursquare Secret
ACCESS_TOKEN = '0EE3WPELNSLRXZMA1V3CBHW0WIMNR05J1DXK3XB405SWPQ52' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 40
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QZNC24IIFPKZRH5NSHQJN3WDFBGPHHO1PP1F5MSQI0DA01KO
# CLIENT_SECRET:PY4UPNJDJRDBRENFIDHVLIJ35QW14QEQBKKFXFE3ZVE1YZYY

# %%
import requests

request_parameters = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "v": '20180605',
    "section": "coffee",
    "near": "Abu Dhabi",
    "radius": 1000,
    "limit": 50}

data = requests.get("https://api.foursquare.com/v2/venues/explore", params=request_parameters)

# %%
print(data)
# Out:
# <Response [200]>

# %%
d = data.json()["response"]
d.keys()
# Out:
# dict_keys(['suggestedFilters', 'geocode', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %%
d["headerLocationGranularity"], d["headerLocation"], d["headerFullLocation"]
# Out:
# ('city', 'Abu Dhabi', 'Abu Dhabi')

# %%
d["suggestedBounds"], d["totalResults"]
# Out:
# ({'ne': {'lat': 24.474474019598837, 'lng': 54.37529872158887},
#   'sw': {'lat': 24.4604264752572, 'lng': 54.36451934059264}},
#  26)

# %%
d["geocode"]
# Out:
# {'what': '',
#  'where': 'abu dhabi',
#  'center': {'lat': 24.46667, 'lng': 54.36667},
#  'displayString': 'Abu Dhabi, United Arab Emirates',
#  'cc': 'AE',
#  'geometry': {'bounds': {'ne': {'lat': 24.535763, 'lng': 54.61956},
#    'sw': {'lat': 24.362686, 'lng': 54.290829}}},
#  'slug': 'abu-dhabi-united-arab-emirates',
#  'longId': '72057594038220904'}

# %%
d["groups"][0].keys()
# Out:
# dict_keys(['type', 'name', 'items'])

# %%
d["groups"][0]["type"], d["groups"][0]["name"]
# Out:
# ('Recommended Places', 'recommended')

# %%
items = d["groups"][0]["items"]
print("number of items: %i" % len(items))
items[0]
# Out:
# number of items: 26
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '51913280498e31f5ebc56846',
#   'name': 'Paul',
#   'location': {'address': 'Al Wahda Mall',
#    'crossStreet': 'Hazza Bin Zayed Rd',
#    'lat': 24.470538877162145,
#    'lng': 54.372617144776605,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 24.470538877162145,
#      'lng': 54.372617144776605}],
#    'cc': 'AE',
#    'city': 'أبوظبي',
#    'state': 'أبوظبي',
#    'country': 'الإمارات العربية المتحدة',
#    'formattedAddress': ['Al Wahda Mall (Hazza Bin Zayed Rd)',
#     'أبوظبي',
#     'الإمارات العربية المتحدة']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-5-51913280498e31f5ebc56846-0'}

# %%
items[1]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4b9883def964a520644535e3',
#   'name': 'Starbucks (ستاربكس)',
#   'location': {'address': 'Al Wahda Mall',
#    'lat': 24.4698585,
#    'lng': 54.3723368,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 24.4698585,
#      'lng': 54.3723368}],
#    'cc': 'AE',
#    'city': 'أبوظبي',
#    'state': 'أبوظبي',
#    'country': 'الإمارات العربية المتحدة',
#    'formattedAddress': ['Al Wahda Mall',
#     'أبوظبي',
#     'الإمارات العربية المتحدة']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-5-4b9883def964a520644535e3-1'}

# %%
df_raw = []
for item in items:
    venue = item["venue"]
    categories, uid, name, location = venue["categories"], venue["id"], venue["name"], venue["location"]
    print(location)
    assert len(categories) == 1
    shortname = categories[0]["shortName"]
    address =  ''
    if hasattr(location, 'address'):
      address = location['address']
    if not "postalCode" in location:
        continue
    postalcode = location["postalCode"]
    lat = location["lat"]
    lng = location["lng"]
    datarow = (uid, name, shortname, address, postalcode, lat, lng)
    df_raw.append(datarow)
df = pd.DataFrame(df_raw, columns=["uid", "name", "shortname", "address", "postalcode", "lat", "lng"])
print("found %i cafes" % len(df))
df.head()
# Out:
# {'address': 'Al Wahda Mall', 'crossStreet': 'Hazza Bin Zayed Rd', 'lat': 24.470538877162145, 'lng': 54.372617144776605, 'labeledLatLngs': [{'label': 'display', 'lat': 24.470538877162145, 'lng': 54.372617144776605}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall (Hazza Bin Zayed Rd)', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall', 'lat': 24.4698585, 'lng': 54.3723368, 'labeledLatLngs': [{'label': 'display', 'lat': 24.4698585, 'lng': 54.3723368}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall', 'lat': 24.470286311930934, 'lng': 54.37284010221936, 'labeledLatLngs': [{'label': 'display', 'lat': 24.470286311930934, 'lng': 54.37284010221936}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'SKMC', 'lat': 24.467944687112574, 'lng': 54.36500931245611, 'labeledLatLngs': [{'label': 'display', 'lat': 24.467944687112574, 'lng': 54.36500931245611}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['SKMC', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall', 'lat': 24.47030034369361, 'lng': 54.3727595169529, 'labeledLatLngs': [{'label': 'display', 'lat': 24.47030034369361, 'lng': 54.3727595169529}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Khalidya St', 'lat': 24.465953638431994, 'lng': 54.36587140573792, 'labeledLatLngs': [{'label': 'display', 'lat': 24.465953638431994, 'lng': 54.36587140573792}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Khalidya St', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda City Tower', 'lat': 24.47178116717288, 'lng': 54.373789330530805, 'labeledLatLngs': [{'label': 'display', 'lat': 24.47178116717288, 'lng': 54.373789330530805}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda City Tower', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Whada Mall', 'lat': 24.470250890208874, 'lng': 54.37284139488266, 'labeledLatLngs': [{'label': 'display', 'lat': 24.470250890208874, 'lng': 54.37284139488266}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Whada Mall', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall, Ground Floor, Hazza Bin Zayed the First St, E19, Al Nahyan', 'lat': 24.470395, 'lng': 54.372694, 'labeledLatLngs': [{'label': 'display', 'lat': 24.470395, 'lng': 54.372694}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall, Ground Floor, Hazza Bin Zayed the First St, E19, Al Nahyan', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall', 'lat': 24.470236217233143, 'lng': 54.37439939238264, 'labeledLatLngs': [{'label': 'display', 'lat': 24.470236217233143, 'lng': 54.37439939238264}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall', 'crossStreet': 'Al Wahda Mall', 'lat': 24.470451831099275, 'lng': 54.3748087497254, 'labeledLatLngs': [{'label': 'display', 'lat': 24.470451831099275, 'lng': 54.3748087497254}], 'cc': 'AE', 'neighborhood': 'Al Wahda', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall (Al Wahda Mall)', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall', 'lat': 24.469345449295254, 'lng': 54.37353119033352, 'labeledLatLngs': [{'label': 'display', 'lat': 24.469345449295254, 'lng': 54.37353119033352}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'lat': 24.472165219636775, 'lng': 54.36856231437202, 'labeledLatLngs': [{'label': 'display', 'lat': 24.472165219636775, 'lng': 54.36856231437202}], 'cc': 'AE', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['الإمارات العربية المتحدة']}
# {'address': 'SKMC', 'lat': 24.46843865429973, 'lng': 54.36660198699533, 'labeledLatLngs': [{'label': 'display', 'lat': 24.46843865429973, 'lng': 54.36660198699533}], 'cc': 'AE', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['SKMC', 'الإمارات العربية المتحدة']}
# {'lat': 24.468451667264418, 'lng': 54.36660016394837, 'labeledLatLngs': [{'label': 'display', 'lat': 24.468451667264418, 'lng': 54.36660016394837}], 'cc': 'AE', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall', 'lat': 24.4702226458811, 'lng': 54.37447277529545, 'labeledLatLngs': [{'label': 'display', 'lat': 24.4702226458811, 'lng': 54.37447277529545}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'lat': 24.470557986912947, 'lng': 54.37197395858018, 'labeledLatLngs': [{'label': 'display', 'lat': 24.470557986912947, 'lng': 54.37197395858018}], 'cc': 'AE', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['الإمارات العربية المتحدة']}
# {'address': 'Airport Road', 'crossStreet': 'Airport Road', 'lat': 24.470379978932108, 'lng': 54.37277197468981, 'labeledLatLngs': [{'label': 'display', 'lat': 24.470379978932108, 'lng': 54.37277197468981}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Airport Road (Airport Road)', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Karama Street', 'lat': 24.461065, 'lng': 54.37098, 'labeledLatLngs': [{'label': 'display', 'lat': 24.461065, 'lng': 54.37098}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Karama Street', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': '11th Street', 'crossStreet': '2nd Street', 'lat': 24.470353666844854, 'lng': 54.37305450439453, 'labeledLatLngs': [{'label': 'display', 'lat': 24.470353666844854, 'lng': 54.37305450439453}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['11th Street (2nd Street)', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall', 'lat': 24.470545218219584, 'lng': 54.37303703249966, 'labeledLatLngs': [{'label': 'display', 'lat': 24.470545218219584, 'lng': 54.37303703249966}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Grand Millinneum', 'lat': 24.471834755428905, 'lng': 54.37376797297549, 'labeledLatLngs': [{'label': 'display', 'lat': 24.471834755428905, 'lng': 54.37376797297549}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Grand Millinneum', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall', 'lat': 24.473835494856033, 'lng': 54.37181911992839, 'labeledLatLngs': [{'label': 'display', 'lat': 24.473835494856033, 'lng': 54.37181911992839}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'lat': 24.471875, 'lng': 54.374332, 'labeledLatLngs': [{'label': 'display', 'lat': 24.471875, 'lng': 54.374332}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['أبوظبي', 'الإمارات العربية المتحدة']}
# {'address': 'Al Wahda Mall', 'lat': 24.47038966102197, 'lng': 54.37277607835695, 'labeledLatLngs': [{'label': 'display', 'lat': 24.47038966102197, 'lng': 54.37277607835695}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Wahda Mall', 'أبوظبي', 'الإمارات العربية المتحدة']}
# {'lat': 24.46947858708627, 'lng': 54.373325941033976, 'labeledLatLngs': [{'label': 'display', 'lat': 24.46947858708627, 'lng': 54.373325941033976}], 'cc': 'AE', 'city': 'أبوظبي', 'state': 'أبوظبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['أبوظبي', 'الإمارات العربية المتحدة']}
# found 0 cafes
# Empty DataFrame
# Columns: [uid, name, shortname, address, postalcode, lat, lng]
# Index: []

# %%
AbuDhabi_center =d["geocode"]["center"]
AbuDhabi_center
# Out:
# {'lat': 24.46667, 'lng': 54.36667}

# %%
from folium import plugins


map_DaNang = folium.Map(location=[24.46667, 54.36667], zoom_start=14)

def add_markers(df):
    for (j, row) in df.iterrows():
        label = folium.Popup(row["name"], parse_html=True)
        folium.CircleMarker(
            [row["lat"], row["lng"]],
            radius=5,
            popup=label,
            color='red',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_DaNang)

add_markers(df)
hm_data = df[["lat", "lng"]].to_numpy().tolist()
map_DaNang.add_child(plugins.HeatMap(hm_data))

map_DaNang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_84fa0697245743d5ad66e16d83f50c23%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_84fa0697245743d5ad66e16d83f50c23%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_84fa0697245743d5ad66e16d83f50c23%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_84fa0697245743d5ad66e16d83f50c23%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
import requests

request_parameters = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "v": '20180605',
    "section": "coffee",
    "near": "Dubai",
    "radius": 1000,
    "limit": 50}

data = requests.get("https://api.foursquare.com/v2/venues/explore", params=request_parameters)

# %%
d = data.json()["response"]

# %%
items = d["groups"][0]["items"]
print("number of items: %i" % len(items))
items[0]
# Out:
# number of items: 38
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4ca9c1e6b0b8236aeefebfe6',
#   'name': 'Starbucks',
#   'location': {'address': 'Emaar Town Centre-Springs',
#    'crossStreet': 'Springs',
#    'lat': 25.05384,
#    'lng': 55.171168,
#    'labeledLatLngs': [{'label': 'display', 'lat': 25.05384, 'lng': 55.171168}],
#    'cc': 'AE',
#    'city': 'دبي',
#    'state': 'دبي',
#    'country': 'الإمارات العربية المتحدة',
#    'formattedAddress': ['Emaar Town Centre-Springs (Springs)',
#     'دبي',
#     'الإمارات العربية المتحدة']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '603902135'}},
#  'referralId': 'e-5-4ca9c1e6b0b8236aeefebfe6-0'}

# %%
df_raw = []
for item in items:
    venue = item["venue"]
    categories, uid, name, location = venue["categories"], venue["id"], venue["name"], venue["location"]
    print(location)
    assert len(categories) == 1
    shortname = categories[0]["shortName"]
    address =  ''
    if hasattr(location, 'address'):
      address = location['address']
    if not "postalCode" in location:
        continue
    postalcode = location["postalCode"]
    lat = location["lat"]
    lng = location["lng"]
    datarow = (uid, name, shortname, address, postalcode, lat, lng)
    df_raw.append(datarow)
df = pd.DataFrame(df_raw, columns=["uid", "name", "shortname", "address", "postalcode", "lat", "lng"])
print("found %i cafes" % len(df))
df.head()
# Out:
# {'address': 'Emaar Town Centre-Springs', 'crossStreet': 'Springs', 'lat': 25.05384, 'lng': 55.171168, 'labeledLatLngs': [{'label': 'display', 'lat': 25.05384, 'lng': 55.171168}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Emaar Town Centre-Springs (Springs)', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Emirates Hills', 'crossStreet': 'Springs Town Centre', 'lat': 25.054054256013583, 'lng': 55.17045203403261, 'labeledLatLngs': [{'label': 'display', 'lat': 25.054054256013583, 'lng': 55.17045203403261}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Emirates Hills (Springs Town Centre)', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'The Lakes', 'lat': 25.079247259545557, 'lng': 55.16743852450573, 'labeledLatLngs': [{'label': 'display', 'lat': 25.079247259545557, 'lng': 55.16743852450573}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['The Lakes', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Meadows Village', 'lat': 25.06382048753157, 'lng': 55.15765805069242, 'labeledLatLngs': [{'label': 'display', 'lat': 25.06382048753157, 'lng': 55.15765805069242}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Meadows Village', 'دبي', 'الإمارات العربية المتحدة']}
# {'crossStreet': 'Jumeirah Islands 1 St', 'lat': 25.064553001378343, 'lng': 55.147908676707814, 'labeledLatLngs': [{'label': 'display', 'lat': 25.064553001378343, 'lng': 55.147908676707814}], 'cc': 'AE', 'neighborhood': 'Jumeirah Islands', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Jumeirah Islands 1 St', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Springs Town Centre', 'lat': 25.058361856574706, 'lng': 55.178875023800394, 'labeledLatLngs': [{'label': 'display', 'lat': 25.058361856574706, 'lng': 55.178875023800394}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Springs Town Centre', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Emaar Business Square', 'lat': 25.067728121013335, 'lng': 55.15487003384221, 'labeledLatLngs': [{'label': 'display', 'lat': 25.067728121013335, 'lng': 55.15487003384221}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Emaar Business Square', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'The Springs Souq', 'lat': 25.0654931, 'lng': 55.1926407, 'labeledLatLngs': [{'label': 'display', 'lat': 25.0654931, 'lng': 55.1926407}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['The Springs Souq', 'دبي', 'الإمارات العربية المتحدة']}
# {'lat': 25.065833, 'lng': 55.192289, 'labeledLatLngs': [{'label': 'display', 'lat': 25.065833, 'lng': 55.192289}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Fortune Executive Tower, Cluster T, JLT', 'lat': 25.078413270128486, 'lng': 55.149195418344945, 'labeledLatLngs': [{'label': 'display', 'lat': 25.078413270128486, 'lng': 55.149195418344945}], 'postalCode': '634334', 'cc': 'AE', 'neighborhood': 'Jumeirah Lakes Towers', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Fortune Executive Tower, Cluster T, JLT', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'The Town Centre', 'lat': 25.053897133123783, 'lng': 55.17121297614347, 'labeledLatLngs': [{'label': 'display', 'lat': 25.053897133123783, 'lng': 55.17121297614347}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['The Town Centre', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Ground Floor,  One Lake Plaza', 'lat': 25.079294, 'lng': 55.150569, 'labeledLatLngs': [{'label': 'display', 'lat': 25.079294, 'lng': 55.150569}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Ground Floor,  One Lake Plaza', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'ONE JLT', 'lat': 25.072987283243357, 'lng': 55.14506994931968, 'labeledLatLngs': [{'label': 'display', 'lat': 25.072987283243357, 'lng': 55.14506994931968}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['ONE JLT', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Jumeirah Lakes Towers Cluster R', 'lat': 25.076641318255763, 'lng': 55.14734985237614, 'labeledLatLngs': [{'label': 'display', 'lat': 25.076641318255763, 'lng': 55.14734985237614}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Jumeirah Lakes Towers Cluster R', 'دبي', 'الإمارات العربية المتحدة']}
# {'crossStreet': 'Al Afnan St', 'lat': 25.066055, 'lng': 55.192165, 'labeledLatLngs': [{'label': 'display', 'lat': 25.066055, 'lng': 55.192165}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Al Afnan St', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Jumeirah Park Community Center', 'crossStreet': 'Al Warood Street', 'lat': 25.043311907456964, 'lng': 55.15933845084925, 'labeledLatLngs': [{'label': 'display', 'lat': 25.043311907456964, 'lng': 55.15933845084925}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Jumeirah Park Community Center (Al Warood Street)', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Cluster H, Concorde Tower', 'crossStreet': 'Jumeirah Lakes Towers', 'lat': 25.070162, 'lng': 55.144133, 'labeledLatLngs': [{'label': 'display', 'lat': 25.070162, 'lng': 55.144133}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Cluster H, Concorde Tower (Jumeirah Lakes Towers)', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'The Greens', 'crossStreet': 'Street 7', 'lat': 25.092071857605024, 'lng': 55.17075178632747, 'labeledLatLngs': [{'label': 'display', 'lat': 25.092071857605024, 'lng': 55.17075178632747}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['The Greens (Street 7)', 'دبي', 'الإمارات العربية المتحدة']}
# {'lat': 25.077343, 'lng': 55.150218, 'labeledLatLngs': [{'label': 'display', 'lat': 25.077343, 'lng': 55.150218}], 'cc': 'AE', 'city': 'JLT', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['JLT', 'الإمارات العربية المتحدة']}
# {'address': 'Emirates Hills', 'lat': 25.067555281202548, 'lng': 55.164642641415924, 'labeledLatLngs': [{'label': 'display', 'lat': 25.067555281202548, 'lng': 55.164642641415924}], 'postalCode': '99999', 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Emirates Hills', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Jumeirah Park Pavilion', 'crossStreet': 'Al Warood 1 St', 'lat': 25.042879355379807, 'lng': 55.160291164055046, 'labeledLatLngs': [{'label': 'display', 'lat': 25.042879355379807, 'lng': 55.160291164055046}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Jumeirah Park Pavilion (Al Warood 1 St)', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Jumeirah Lake Towers, Cluster Q,', 'lat': 25.076666049386947, 'lng': 55.14680968752602, 'labeledLatLngs': [{'label': 'display', 'lat': 25.076666049386947, 'lng': 55.14680968752602}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Jumeirah Lake Towers, Cluster Q,', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'MAG Tower 214, Shop 3', 'lat': 25.076380637671637, 'lng': 55.14742139553849, 'labeledLatLngs': [{'label': 'display', 'lat': 25.076380637671637, 'lng': 55.14742139553849}], 'cc': 'AE', 'city': 'JLT', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['MAG Tower 214, Shop 3', 'JLT', 'الإمارات العربية المتحدة']}
# {'address': 'Jumierah Park Pavilion', 'lat': 25.042915786755653, 'lng': 55.15928454816476, 'labeledLatLngs': [{'label': 'display', 'lat': 25.042915786755653, 'lng': 55.15928454816476}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Jumierah Park Pavilion', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Jumeirah Lakes Towers, Cluster X, Jumeirah Bay Tower X2, Sheikh Zayed Rd', 'lat': 25.079686, 'lng': 55.152704, 'labeledLatLngs': [{'label': 'display', 'lat': 25.079686, 'lng': 55.152704}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Jumeirah Lakes Towers, Cluster X, Jumeirah Bay Tower X2, Sheikh Zayed Rd', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Jumeirah Lakes Tower', 'crossStreet': 'O Cluster', 'lat': 25.073840952623133, 'lng': 55.144286155700684, 'labeledLatLngs': [{'label': 'display', 'lat': 25.073840952623133, 'lng': 55.144286155700684}], 'postalCode': 'P.O Box 1218', 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Jumeirah Lakes Tower (O Cluster)', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Gold Tower', 'crossStreet': 'Cluster I', 'lat': 25.06907622719589, 'lng': 55.14350941301414, 'labeledLatLngs': [{'label': 'display', 'lat': 25.06907622719589, 'lng': 55.14350941301414}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Gold Tower (Cluster I)', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Platinum Tower', 'lat': 25.06900320210247, 'lng': 55.142793319472304, 'labeledLatLngs': [{'label': 'display', 'lat': 25.06900320210247, 'lng': 55.142793319472304}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Platinum Tower', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Shop G08, Dubai Gate One Bldg, Cluster Q', 'lat': 25.07620064992479, 'lng': 55.145809530513304, 'labeledLatLngs': [{'label': 'display', 'lat': 25.07620064992479, 'lng': 55.145809530513304}], 'postalCode': '488183', 'cc': 'AE', 'neighborhood': 'Jumeirah Lakes Towers (JLT)', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Shop G08, Dubai Gate One Bldg, Cluster Q', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'One JLT', 'crossStreet': 'Jumeirah Lakes Towers', 'lat': 25.072567, 'lng': 55.14475, 'labeledLatLngs': [{'label': 'display', 'lat': 25.072567, 'lng': 55.14475}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['One JLT (Jumeirah Lakes Towers)', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Jumeirah Pavilion Park', 'lat': 25.044424686551295, 'lng': 55.15825501342361, 'labeledLatLngs': [{'label': 'display', 'lat': 25.044424686551295, 'lng': 55.15825501342361}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Jumeirah Pavilion Park', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Geant Easy Jumeirah Park', 'lat': 25.043024536342514, 'lng': 55.16023863070978, 'labeledLatLngs': [{'label': 'display', 'lat': 25.043024536342514, 'lng': 55.16023863070978}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Geant Easy Jumeirah Park', 'دبي', 'الإمارات العربية المتحدة']}
# {'lat': 25.074351520672135, 'lng': 55.14460811381372, 'labeledLatLngs': [{'label': 'display', 'lat': 25.074351520672135, 'lng': 55.14460811381372}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['دبي', 'الإمارات العربية المتحدة']}
# {'address': 'Pullman Hotel', 'lat': 25.079664155742197, 'lng': 55.15019296216204, 'labeledLatLngs': [{'label': 'display', 'lat': 25.079664155742197, 'lng': 55.15019296216204}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['Pullman Hotel', 'دبي', 'الإمارات العربية المتحدة']}
# {'lat': 25.065612, 'lng': 55.192464, 'labeledLatLngs': [{'label': 'display', 'lat': 25.065612, 'lng': 55.192464}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['دبي', 'الإمارات العربية المتحدة']}
# {'address': 'The Springs Souk, Afnan St, Springs 7', 'crossStreet': 'Alafnan Street', 'lat': 25.065662, 'lng': 55.192565, 'labeledLatLngs': [{'label': 'display', 'lat': 25.065662, 'lng': 55.192565}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['The Springs Souk, Afnan St, Springs 7 (Alafnan Street)', 'دبي', 'الإمارات العربية المتحدة']}
# {'address': 'The Springs Souk', 'lat': 25.06562, 'lng': 55.192648, 'labeledLatLngs': [{'label': 'display', 'lat': 25.06562, 'lng': 55.192648}], 'cc': 'AE', 'city': 'دبي', 'state': 'دبي', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['The Springs Souk', 'دبي', 'الإمارات العربية المتحدة']}
# {'lat': 25.082428598656904, 'lng': 55.148157396508914, 'labeledLatLngs': [{'label': 'display', 'lat': 25.082428598656904, 'lng': 55.148157396508914}], 'cc': 'AE', 'country': 'الإمارات العربية المتحدة', 'formattedAddress': ['الإمارات العربية المتحدة']}
# found 4 cafes
#                         uid                     name    shortname address  \
# 0  54f161e4498e1e5f53041c7d  Friends Avenue Cafe JLT         Café
# 1  4be927aa947820a1b4a8b5db           Monty Cristo's     Tea Room
# 2  5063d45ee4b0d41cab6ea56a             Caffe Divino  Coffee Shop
# 3  5038ad53e4b0c1904eb6c78a        Baker Street Cafe       Bistro
#
#      postalcode        lat        lng
# 0        634334  25.078413  55.149195
# 1         99999  25.067555  55.164643
# 2  P.O Box 1218  25.073841  55.144286
# 3        488183  25.076201  55.145810

# %%
Dubai_center =d["geocode"]["center"]
Dubai_center
# Out:
# {'lat': 25.0657, 'lng': 55.17128}

# %%
from folium import plugins


map_DaNang = folium.Map(location=[25.0657, 55.17128], zoom_start=14)

def add_markers(df):
    for (j, row) in df.iterrows():
        label = folium.Popup(row["name"], parse_html=True)
        folium.CircleMarker(
            [row["lat"], row["lng"]],
            radius=5,
            popup=label,
            color='red',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_DaNang)

add_markers(df)
hm_data = df[["lat", "lng"]].to_numpy().tolist()
map_DaNang.add_child(plugins.HeatMap(hm_data))

map_DaNang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_da5403947b594de19215d9944d16c72f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_da5403947b594de19215d9944d16c72f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_da5403947b594de19215d9944d16c72f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_da5403947b594de19215d9944d16c72f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...
